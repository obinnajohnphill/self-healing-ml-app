# %%
import pandas as pd
from pycaret.classification import setup, compare_models, finalize_model, predict_model, pull
import gc

# Function to free up memory
def free_memory():
    gc.collect()

# Load Windows dataset
file_path = 'dataset/system-logs/multiple-system-log-dataset/preprocessed-data/Windows_preprocessed.csv'
df = pd.read_csv(file_path)

# Reduce the dataset size significantly for faster processing (if necessary)
df = df.sample(frac=0.05, random_state=42)  # Use 5% of the data

# Check class distribution
print("Class distribution in Windows:")
print(df['error'].value_counts())

# Setup the data in PyCaret with reduced verbosity and fewer folds
try:
    setup_data = setup(data=df, target='error', session_id=42, fold=3, fix_imbalance=False, verbose=False)
except MemoryError:
    print("Memory error during setup. Please try reducing the data size further.")
    exit()

# Compare all models
try:
    best_models = compare_models(n_select=3)  # Select top 3 models
except MemoryError:
    print("Memory error during model comparison. Exiting.")
    exit()

# Iterate through each model, finalize, and make predictions
for model in best_models:
    try:
        # Finalize the model
        final_model = finalize_model(model)

        # Free memory before making predictions
        free_memory()

        # Display the final model performance
        print(f"Final tuned model performance for {model}:")
        predictions = predict_model(final_model)
        print(predictions)
        
        # Pull and print the metrics
        metrics = pull()
        print(metrics)

    except MemoryError:
        print(f"Memory error during processing model {model}. Skipping.")
        continue

# Additional memory management
free_memory()
# Out:
# Class distribution in Windows:
# 0    5704647
# 1      16468
# Name: error, dtype: int64
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         22:41:50
# Status                     Fitting 3 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_0d4a8 th {
#   text-align: left;
# }
# #T_0d4a8_row0_col0, #T_0d4a8_row0_col1, #T_0d4a8_row0_col2, #T_0d4a8_row0_col3, #T_0d4a8_row0_col4, #T_0d4a8_row0_col5, #T_0d4a8_row0_col6, #T_0d4a8_row0_col7, #T_0d4a8_row0_col8, #T_0d4a8_row1_col0, #T_0d4a8_row1_col1, #T_0d4a8_row1_col2, #T_0d4a8_row1_col3, #T_0d4a8_row1_col4, #T_0d4a8_row1_col5, #T_0d4a8_row1_col6, #T_0d4a8_row1_col7, #T_0d4a8_row1_col8, #T_0d4a8_row2_col0, #T_0d4a8_row2_col1, #T_0d4a8_row2_col2, #T_0d4a8_row2_col3, #T_0d4a8_row2_col4, #T_0d4a8_row2_col5, #T_0d4a8_row2_col6, #T_0d4a8_row2_col7, #T_0d4a8_row2_col8, #T_0d4a8_row3_col0, #T_0d4a8_row3_col1, #T_0d4a8_row3_col2, #T_0d4a8_row3_col3, #T_0d4a8_row3_col4, #T_0d4a8_row3_col5, #T_0d4a8_row3_col6, #T_0d4a8_row3_col7, #T_0d4a8_row3_col8, #T_0d4a8_row4_col0, #T_0d4a8_row4_col1, #T_0d4a8_row4_col2, #T_0d4a8_row4_col3, #T_0d4a8_row4_col4, #T_0d4a8_row4_col5, #T_0d4a8_row4_col6, #T_0d4a8_row4_col7, #T_0d4a8_row4_col8, #T_0d4a8_row5
row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_0d4a8_row1_col5" class="data row1 col5" >0.9864</td>
#       <td id="T_0d4a8_row1_col6" class="data row1 col6" >0.9864</td>
#       <td id="T_0d4a8_row1_col7" class="data row1 col7" >0.9865</td>
#       <td id="T_0d4a8_row1_col8" class="data row1 col8" >3.5000</td>
#     </tr>
#     <tr>
#       <th id="T_0d4a8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_0d4a8_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_0d4a8_row2_col1" class="data row2 col1" >0.9999</td>
#       <td id="T_0d4a8_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_0d4a8_row2_col3" class="data row2 col3" >0.9732</td>
#       <td id="T_0d4a8_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_0d4a8_row2_col5" class="data row2 col5" >0.9864</td>
#       <td id="T_0d4a8_row2_col6" class="data row2 col6" >0.9864</td>
#       <td id="T_0d4a8_row2_col7" class="data row2 col7" >0.9865</td>
#       <td id="T_0d4a8_row2_col8" class="data row2 col8" >8.5967</td>
#     </tr>
#     <tr>
#       <th id="T_0d4a8_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_0d4a8_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_0d4a8_row3_col1" class="data row3 col1" >0.9999</td>
#       <td id="T_0d4a8_row3_col2" class="data row3 col2" >0.9866</td>
#       <td id="T_0d4a8_row3_col3" class="data row3 col3" >0.9732</td>
#       <td id="T_0d4a8_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_0d4a8_row3_col5" class="data row3 col5" >0.9864</td>
#       <td id="T_0d4a8_row3_col6" class="data row3 col6" >0.9864</td>
#       <td id="T_0d4a8_row3_col7" class="data row3 col7" >0.9865</td>
#       <td id="T_0d4a8_row3_col8" class="data row3 col8" >3.3433</td>
#     </tr>
#     <tr>
#       <th id="T_0d4a8_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_0d4a8_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0d4a8_row4_col1" class="data row4 col1" >0.9999</td>
#       <td id="T_0d4a8_row4_col2" class="data row4 col2" >0.9793</td>
#       <td id="T_0d4a8_row4_col3" class="data row4 col3" >0.9732</td>
#       <td id="T_0d4a8_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_0d4a8_row4_col5" class="data row4 col5" >0.9864</td>
#       <td id="T_0d4a8_row4_col6" class="data row4 col6" >0.9864</td>
#       <td id="T_0d4a8_row4_col7" class="data row4 col7" >0.9865</td>
#       <td id="T_0d4a8_row4_col8" class="data row4 col8" >14.7600</td>
#     </tr>
#     <tr>
#       <th id="T_0d4a8_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_0d4a8_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_0d4a8_row5_col1" class="data row5 col1" >0.9999</td>
#       <td id="T_0d4a8_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_0d4a8_row5_col3" class="data row5 col3" >0.9732</td>
#       <td id="T_0d4a8_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_0d4a8_row5_col5" class="data row5 col5" >0.9864</td>
#       <td id="T_0d4a8_row5_col6" class="data row5 col6" >0.9864</td>
#       <td id="T_0d4a8_row5_col7" class="data row5 col7" >0.9865</td>
#       <td id="T_0d4a8_row5_col8" class="data row5 col8" >5.7867</td>
#     </tr>
#     <tr>
#       <th id="T_0d4a8_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_0d4a8_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_0d4a8_row6_col1" class="data row6 col1" >0.9998</td>
#       <td id="T_0d4a8_row6_col2" class="data row6 col2" >0.9993</td>
#       <td id="T_0d4a8_row6_col3" class="data row6 col3" >0.9305</td>
#       <td id="T_0d4a8_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_0d4a8_row6_col5" class="data row6 col5"
# Processing:   0%|          | 0/63 [00:00<?, ?it/s]
