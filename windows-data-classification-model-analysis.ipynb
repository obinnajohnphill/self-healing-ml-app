# %%
import pandas as pd
from pycaret.classification import setup, compare_models, finalize_model, predict_model, pull
import gc

# Function to free up memory
def free_memory():
    gc.collect()

# Load Windows dataset
file_path = 'dataset/system-logs/multiple-system-log-dataset/preprocessed-data/Windows_preprocessed.csv'
df = pd.read_csv(file_path)

# Reduce the dataset size significantly for faster processing (if necessary)
df = df.sample(frac=0.05, random_state=42)  # Use 5% of the data

# Check class distribution
print("Class distribution in Windows:")
print(df['error'].value_counts())

# Setup the data in PyCaret with reduced verbosity and fewer folds
try:
    setup_data = setup(data=df, target='error', session_id=42, fold=3, fix_imbalance=False, verbose=False)
except MemoryError:
    print("Memory error during setup. Please try reducing the data size further.")
    exit()

# Compare all models
try:
    best_models = compare_models(n_select=3)  # Select top 3 models
except MemoryError:
    print("Memory error during model comparison. Exiting.")
    exit()

# Iterate through each model, finalize, and make predictions
for model in best_models:
    try:
        # Finalize the model
        final_model = finalize_model(model)

        # Free memory before making predictions
        free_memory()

        # Display the final model performance
        print(f"Final tuned model performance for {model}:")
        predictions = predict_model(final_model)
        print(predictions)
        
        # Pull and print the metrics
        metrics = pull()
        print(metrics)

    except MemoryError:
        print(f"Memory error during processing model {model}. Skipping.")
        continue

# Additional memory management
free_memory()
# Out:
# Class distribution in Windows:
# 0    5704647
# 1      16468
# Name: error, dtype: int64
# <style type="text/css">
# #T_6fcba th {
#   text-align: left;
# }
# #T_6fcba_row0_col0, #T_6fcba_row0_col2, #T_6fcba_row0_col3, #T_6fcba_row1_col0, #T_6fcba_row1_col2, #T_6fcba_row1_col3, #T_6fcba_row2_col0, #T_6fcba_row2_col2, #T_6fcba_row2_col3, #T_6fcba_row3_col0, #T_6fcba_row3_col2, #T_6fcba_row3_col3, #T_6fcba_row4_col0, #T_6fcba_row4_col2, #T_6fcba_row4_col3, #T_6fcba_row5_col0, #T_6fcba_row5_col2, #T_6fcba_row5_col3, #T_6fcba_row6_col0, #T_6fcba_row6_col2, #T_6fcba_row6_col3, #T_6fcba_row7_col0, #T_6fcba_row7_col1, #T_6fcba_row7_col2, #T_6fcba_row7_col3, #T_6fcba_row7_col5, #T_6fcba_row7_col6, #T_6fcba_row7_col7, #T_6fcba_row8_col0, #T_6fcba_row8_col1, #T_6fcba_row8_col3, #T_6fcba_row8_col5, #T_6fcba_row8_col6, #T_6fcba_row8_col7, #T_6fcba_row9_col0, #T_6fcba_row9_col1, #T_6fcba_row9_col2, #T_6fcba_row9_col3, #T_6fcba_row9_col5, #T_6fcba_row9_col6, #T_6fcba_row9_col7, #T_6fcba_row10_col0, #T_6fcba_row10_col1, #T_6fcba_row10_col2, #T_6fcba_row10_col3, #T_6fcba_row10_col5, #T_6fcba_row10_col6, #T_6fcba_row10_col7, #T_6fcba_row11_col0, #T_6fcba_row11_col1, #T_6fcba_row11_col2, #T_6fcba_row11_col3, #T_6fcba_row11_col4, #T_6fcba_row11_col5, #T_6fcba_row11_col6, #T_6fcba_row11_col7, #T_6fcba_row12_col0, #T_6fcba_row12_col1, #T_6fcba_row12_col2, #T_6fcba_row12_col3, #T_6fcba_row12_col4, #T_6fcba_row12_col5, #T_6fcba_row12_col6, #T_6fcba_row12_col7, #T_6fcba_row13_col0, #T_6fcba_row13_col1, #T_6fcba_row13_col2, #T_6fcba_row13_col3, #T_6fcba_row13_col4, #T_6fcba_row13_col5, #T_6fcba_row13_col6, #T_6fcba_row13_col7, #T_6fcba_row14_col0, #T_6fcba_row14_col1, #T_6fcba_row14_col2, #T_6fcba_row14_col4, #T_6fcba_row14_col5, #T_6fcba_row14_col6, #T_6fcba_row14_col7 {
#   text-align: left;
# }
# #T_6fcba_row0_col1, #T_6fcba_row0_col4, #T_6fcba_row0_col5, #T_6fcba_row0_col6, #T_6fcba_row0_col7, #T_6fcba_row1_col1, #T_6fcba_row1_col4, #T_6fcba_row1_col5, #T_6fcba_row1_col6, #T_6fcba_row1_col7, #T_6fcba_row2_col1, #T_6fcba_row2_col4, #T_6fcba_row2_col5, #T_6fcba_row2_col6, #T_6fcba_row2_col7, #T_6fcba_row3_col1, #T_6fcba_row3_col4, #T_6fcba_row3_col5, #T_6fcba_row3_col6, #T_6fcba_row3_col7, #T_6fcba_row4_col1, #T_6fcba_row4_col4, #T_6fcba_row4_col5, #T_6fcba_row4_col6, #T_6fcba_row4_col7, #T_6fcba_row5_col1, #T_6fcba_row5_col4, #T_6fcba_row5_col5, #T_6fcba_row5_col6, #T_6fcba_row5_col7, #T_6fcba_row6_col1, #T_6fcba_row6_col4, #T_6fcba_row6_col5, #T_6fcba_row6_col6, #T_6fcba_row6_col7, #T_6fcba_row7_col4, #T_6fcba_row8_col2, #T_6fcba_row8_col4, #T_6fcba_row9_col4, #T_6fcba_row10_col4, #T_6fcba_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6fcba_row0_col8, #T_6fcba_row1_col8, #T_6fcba_row2_col8, #T_6fcba_row3_col8, #T_6fcba_row4_col8, #T_6fcba_row5_col8, #T_6fcba_row6_col8, #T_6fcba_row7_col8, #T_6fcba_row8_col8, #T_6fcba_row9_col8, #T_6fcba_row10_col8, #T_6fcba_row11_col8, #T_6fcba_row12_col8, #T_6fcba_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6fcba_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6fcba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fcba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6fcba_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6fcba_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6fcba_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6fcba_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6fcba_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6fcba_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6fcba_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6fcba_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fcba_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_6fcba_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_6fcba_row0_col1" class="data row0 col1" >0.9999</td>
#       <td id="T_6fcba_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_6fcba_row0_col3" class="data row0 col3" >0.9732</td>
#       <td id="T_6fcba_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_6fcba_row0_col5" class="data row0 col5" >0.9864</td>
#       <td id="T_6fcba_row0_col6" class="data row0 col6" >0.9864</td>
#       <td id="T_6fcba_row0_col7" class="data row0 col7" >0.9865</td>
#       <td id="T_6fcba_row0_col8" class="data row0 col8" >42.1633</td>
#     </tr>
#     <tr>
#       <th id="T_6fcba_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_6fcba_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_6fcba_row1_col1" class="data row1 col1" >0.9999</td>
#       <td id="T_6fcba_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_6fcba_row1_col3" class="data row1 col3" >0.9732</td>
#       <td id="T_6fcba_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_6fcba_row1_col5" class="data row1 col5" >0.9864</td>
#       <td id="T_6fcba_row1_col6" class="data row1 col6" >0.9864</td>
#       <td id="T_6fcba_row1_col7" class="data row1 col7" >0.9865</td>
#       <td id="T_6fcba_row1_col8" class="data row1 col8" >8.3033</td>
#     </tr>
#     <tr>
#       <th id="T_6fcba_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_6fcba_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_6fcba_row2_col1" class="data row2 col1" >0.9999</td>
#       <td id="T_6fcba_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_6fcba_row2_col3" class="data row2 col3" >0.9732</td>
#       <td id="T_6fcba_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_6fcba_row2_col5" class="data row2 col5" >0.9864</td>
#       <td id="T_6fcba_row2_col6" class="data row2 col6" >0.9864</td>
#       <td id="T_6fcba_row2_col7" class="data row2 col7" >0.9865</td>
#       <td id="T_6fcba_row2_col8" class="data row2 col8" >15.7833</td>
#     </tr>
#     <tr>
#       <th id="T_6fcba_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_6fcba_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_6fcba_row3_col1" class="data row3 col1" >0.9999</td>
#       <td id="T_6fcba_row3_col2" class="data row3 col2" >0.9866</td>
#       <td id="T_6fcba_row3_col3" class="data row3 col3" >0.9732</td>
#       <td id="T_6fcba_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_6fcba_row3_col5" class="data row3 col5" >0.9864</td>
#       <td id="T_6fcba_row3_col6" class="data row3 col6" >0.9864</td>
#       <td id="T_6fcba_row3_col7" class="data row3 col7" >0.9865</td>
#       <td id="T_6fcba_row3_col8" class="data row3 col8" >15.2967</td>
#     </tr>
#     <tr>
#       <th id="T_6fcba_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_6fcba_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6fcba_row4_col1" class="data row4 col1" >0.9999</td>
#       <td id="T_6fcba_row4_col2" class="data row4 col2" >0.9793</td>
#       <td id="T_6fcba_row4_col3" class="data row4 col3" >0.9732</td>
#       <td id="T_6fcba_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_6fcba_row4_col5" class="data row4 col5" >0.9864</td>
#       <td id="T_6fcba_row4_col6" class="data row4 col6" >0.9864</td>
#       <td id="T_6fcba_row4_col7" class="data row4 col7" >0.9865</td>
#       <td id="T_6fcba_row4_col8" class="data row4 col8" >20.9833</td>
#     </tr>
#     <tr>
#       <th id="T_6fcba_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_6fcba_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_6fcba_row5_col1" class="data row5 col1" >0.9999</td>
#       <td id="T_6fcba_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_6fcba_row5_col3" class="data row5 col3" >0.9732</td>
#       <td id="T_6fcba_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_6fcba_row5_co
# Processing:   0%|          | 0/67 [00:00<?, ?it/s]
# Final tuned model performance for KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform'):
# <style type="text/css">
# </style>
# <table id="T_ef2a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef2a4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ef2a4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ef2a4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ef2a4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ef2a4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ef2a4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ef2a4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ef2a4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef2a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef2a4_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_ef2a4_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_ef2a4_row0_col2" class="data row0 col2" >0.9929</td>
#       <td id="T_ef2a4_row0_col3" class="data row0 col3" >0.9858</td>
#       <td id="T_ef2a4_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_ef2a4_row0_col5" class="data row0 col5" >0.9929</td>
#       <td id="T_ef2a4_row0_col6" class="data row0 col6" >0.9928</td>
#       <td id="T_ef2a4_row0_col7" class="data row0 col7" >0.9929</td>
#     </tr>
#   </tbody>
# </table>
#                      timestamp  \
# 65904285   2016-02-15 03:04:57
# 21875662   2015-05-19 03:01:20
# 37568917   2015-09-14 03:12:43
# 50721232   2015-11-16 03:15:57
# 108496704  2017-03-16 03:02:44
# ...                        ...
# 46443425   2015-10-19 03:24:39
# 108950892  2017-03-21 03:10:56
# 1388595    2016-10-17 03:17:43
# 24403704   2015-06-15 03:03:19
# 17642834   2015-05-10 15:16:40
#
#                                                       tokens  warning  \
# 65904285   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 21875662   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 37568917   [',', 'Info', 'CBS', 'Appl:', 'Selfupdate,', '...        0
# 50721232   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 108496704  [',', 'Info', 'CBS', 'Appl:', 'detect', 'Paren...        0
# ...                                                      ...      ...
# 46443425   [',', 'Info', 'CBS', 'Appl:', 'detect', 'Paren...        0
# 108950892  [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 1388595    [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 24403704   [',', 'Info', 'CBS', 'Appl:', 'Package:', 'Pac...        0
# 17642834   [',', 'Info', 'CBS', 'Appl:', 'Selfupdate,', '...        0
#
#              Label  error  prediction_label  prediction_score
# 65904285   Windows      0                 0               1.0
# 21875662   Windows      0                 0               1.0
# 37568917   Windows      0                 0               1.0
# 50721232   Windows      0                 0               1.0
# 108496704  Windows      0                 0               1.0
# ...            ...    ...               ...               ...
# 46443425   Windows      0                 0               1.0
# 108950892  Windows      0                 0               1.0
# 1388595    Windows      0                 0               1.0
# 24403704   Windows      0                 0               1.0
# 17642834   Windows      0                 0               1.0
#
# [1716335 rows x 7 columns]
#                     Model  Accuracy     AUC  Recall  Prec.      F1   Kappa  \
# 0  K Neighbors Classifier       1.0  0.9929  0.9858    1.0  0.9929  0.9928
#
#       MCC
# 0  0.9929
# Final tuned model performance for DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=42, splitter='best'):
# <style type="text/css">
# </style>
# <table id="T_1bbbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bbbe_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1bbbe_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1bbbe_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1bbbe_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1bbbe_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1bbbe_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1bbbe_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1bbbe_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bbbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bbbe_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_1bbbe_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_1bbbe_row0_col2" class="data row0 col2" >0.9929</td>
#       <td id="T_1bbbe_row0_col3" class="data row0 col3" >0.9858</td>
#       <td id="T_1bbbe_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_1bbbe_row0_col5" class="data row0 col5" >0.9929</td>
#       <td id="T_1bbbe_row0_col6" class="data row0 col6" >0.9928</td>
#       <td id="T_1bbbe_row0_col7" class="data row0 col7" >0.9929</td>
#     </tr>
#   </tbody>
# </table>
#                      timestamp  \
# 65904285   2016-02-15 03:04:57
# 21875662   2015-05-19 03:01:20
# 37568917   2015-09-14 03:12:43
# 50721232   2015-11-16 03:15:57
# 108496704  2017-03-16 03:02:44
# ...                        ...
# 46443425   2015-10-19 03:24:39
# 108950892  2017-03-21 03:10:56
# 1388595    2016-10-17 03:17:43
# 24403704   2015-06-15 03:03:19
# 17642834   2015-05-10 15:16:40
#
#                                                       tokens  warning  \
# 65904285   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 21875662   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 37568917   [',', 'Info', 'CBS', 'Appl:', 'Selfupdate,', '...        0
# 50721232   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 108496704  [',', 'Info', 'CBS', 'Appl:', 'detect', 'Paren...        0
# ...                                                      ...      ...
# 46443425   [',', 'Info', 'CBS', 'Appl:', 'detect', 'Paren...        0
# 108950892  [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 1388595    [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 24403704   [',', 'Info', 'CBS', 'Appl:', 'Package:', 'Pac...        0
# 17642834   [',', 'Info', 'CBS', 'Appl:', 'Selfupdate,', '...        0
#
#              Label  error  prediction_label  prediction_score
# 65904285   Windows      0                 0               1.0
# 21875662   Windows      0                 0               1.0
# 37568917   Windows      0                 0               1.0
# 50721232   Windows      0                 0               1.0
# 108496704  Windows      0                 0               1.0
# ...            ...    ...               ...               ...
# 46443425   Windows      0                 0               1.0
# 108950892  Windows      0                 0               1.0
# 1388595    Windows      0                 0               1.0
# 24403704   Windows      0                 0               1.0
# 17642834   Windows      0                 0               1.0
#
# [1716335 rows x 7 columns]
#                       Model  Accuracy     AUC  Recall  Prec.      F1   Kappa  \
# 0  Decision Tree Classifier       1.0  0.9929  0.9858    1.0  0.9929  0.9928
#
#       MCC
# 0  0.9929
# Final tuned model performance for RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=42, verbose=0,
#                        warm_start=False):
# <style type="text/css">
# </style>
# <table id="T_94937">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94937_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_94937_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_94937_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_94937_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_94937_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_94937_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_94937_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_94937_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94937_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94937_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_94937_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_94937_row0_col2" class="data row0 col2" >0.9929</td>
#       <td id="T_94937_row0_col3" class="data row0 col3" >0.9858</td>
#       <td id="T_94937_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_94937_row0_col5" class="data row0 col5" >0.9929</td>
#       <td id="T_94937_row0_col6" class="data row0 col6" >0.9928</td>
#       <td id="T_94937_row0_col7" class="data row0 col7" >0.9929</td>
#     </tr>
#   </tbody>
# </table>
#                      timestamp  \
# 65904285   2016-02-15 03:04:57
# 21875662   2015-05-19 03:01:20
# 37568917   2015-09-14 03:12:43
# 50721232   2015-11-16 03:15:57
# 108496704  2017-03-16 03:02:44
# ...                        ...
# 46443425   2015-10-19 03:24:39
# 108950892  2017-03-21 03:10:56
# 1388595    2016-10-17 03:17:43
# 24403704   2015-06-15 03:03:19
# 17642834   2015-05-10 15:16:40
#
#                                                       tokens  warning  \
# 65904285   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 21875662   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 37568917   [',', 'Info', 'CBS', 'Appl:', 'Selfupdate,', '...        0
# 50721232   [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 108496704  [',', 'Info', 'CBS', 'Appl:', 'detect', 'Paren...        0
# ...                                                      ...      ...
# 46443425   [',', 'Info', 'CBS', 'Appl:', 'detect', 'Paren...        0
# 108950892  [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 1388595    [',', 'Info', 'CBS', 'Applicability(ComponentA...        0
# 24403704   [',', 'Info', 'CBS', 'Appl:', 'Package:', 'Pac...        0
# 17642834   [',', 'Info', 'CBS', 'Appl:', 'Selfupdate,', '...        0
#
#              Label  error  prediction_label  prediction_score
# 65904285   Windows      0                 0               1.0
# 21875662   Windows      0                 0               1.0
# 37568917   Windows      0                 0               1.0
# 50721232   Windows      0                 0               1.0
# 108496704  Windows      0                 0               1.0
# ...            ...    ...               ...               ...
# 46443425   Windows      0                 0               1.0
# 108950892  Windows      0                 0               1.0
# 1388595    Windows      0                 0               1.0
# 24403704   Windows      0                 0               1.0
# 17642834   Windows      0                 0               1.0
#
# [1716335 rows x 7 columns]
#                       Model  Accuracy     AUC  Recall  Prec.      F1   Kappa  \
# 0  Random Forest Classifier       1.0  0.9929  0.9858    1.0  0.9929  0.9928
#
#       MCC
# 0  0.9929
