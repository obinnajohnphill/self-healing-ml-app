# %%
import pandas as pd
from pycaret.classification import setup, compare_models, tune_model, finalize_model, predict_model

# Load Linux dataset
file_path = 'dataset/system-logs/multiple-system-log-dataset/preprocessed-data/Linux_preprocessed.csv'
df = pd.read_csv(file_path)

# Check class distribution
print("Class distribution in Linux:")
print(df['error'].value_counts())

# Setup the data in PyCaret without automatic imbalance handling
setup_data = setup(data=df, target='error', session_id=42, fold=10, fix_imbalance=False, verbose=True)

# Compare and evaluate models
best_model = compare_models()
tuned_best_model = tune_model(best_model, optimize='AUC', n_iter=30)
final_model = finalize_model(tuned_best_model)

# Displaying the final model
print("Final tuned model performance for Linux:")
predict_model(final_model)
# Out:
# Class distribution in Linux:
# 0    25152
# 1      415
# Name: error, dtype: int64
# <style type="text/css">
# #T_3a3ab_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3a3ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a3ab_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3a3ab_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a3ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a3ab_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3a3ab_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a3ab_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3a3ab_row1_col1" class="data row1 col1" >error</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a3ab_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3a3ab_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a3ab_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3a3ab_row3_col1" class="data row3 col1" >(25567, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a3ab_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3a3ab_row4_col1" class="data row4 col1" >(25567, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a3ab_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3a3ab_row5_col1" class="data row5 col1" >(17896, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a3ab_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3a3ab_row6_col1" class="data row6 col1" >(7671, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a3ab_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3a3ab_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a3ab_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_3a3ab_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3a3ab_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_3a3ab_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3a3ab_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_3a3ab_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3a3ab_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_3a3ab_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3a3ab_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_3a3ab_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3a3ab_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_3a3ab_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3a3ab_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_3a3ab_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3a3ab_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_3a3ab_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3a3ab_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_3a3ab_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3a3ab_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_3a3ab_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3a3ab_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_3a3ab_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3a3ab_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_3a3ab_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3a3ab_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_3a3ab_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3a3ab_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3a3ab_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_3a3ab_row21_col1" class="data row21 col1" >11fb</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c20af th {
#   text-align: left;
# }
# #T_c20af_row0_col0, #T_c20af_row0_col2, #T_c20af_row0_col4, #T_c20af_row1_col0, #T_c20af_row1_col1, #T_c20af_row1_col2, #T_c20af_row1_col3, #T_c20af_row1_col5, #T_c20af_row1_col6, #T_c20af_row1_col7, #T_c20af_row2_col0, #T_c20af_row2_col1, #T_c20af_row2_col2, #T_c20af_row2_col3, #T_c20af_row2_col5, #T_c20af_row2_col6, #T_c20af_row2_col7, #T_c20af_row3_col0, #T_c20af_row3_col1, #T_c20af_row3_col3, #T_c20af_row3_col5, #T_c20af_row3_col6, #T_c20af_row3_col7, #T_c20af_row4_col0, #T_c20af_row4_col1, #T_c20af_row4_col2, #T_c20af_row4_col3, #T_c20af_row4_col5, #T_c20af_row4_col6, #T_c20af_row4_col7, #T_c20af_row5_col0, #T_c20af_row5_col1, #T_c20af_row5_col2, #T_c20af_row5_col3, #T_c20af_row5_col5, #T_c20af_row5_col6, #T_c20af_row5_col7, #T_c20af_row6_col0, #T_c20af_row6_col1, #T_c20af_row6_col2, #T_c20af_row6_col3, #T_c20af_row6_col5, #T_c20af_row6_col6, #T_c20af_row6_col7, #T_c20af_row7_col0, #T_c20af_row7_col1, #T_c20af_row7_col2, #T_c20af_row7_col3, #T_c20af_row7_col5, #T_c20af_row7_col6, #T_c20af_row7_col7, #T_c20af_row8_col0, #T_c20af_row8_col1, #T_c20af_row8_col2, #T_c20af_row8_col3, #T_c20af_row8_col5, #T_c20af_row8_col6, #T_c20af_row8_col7, #T_c20af_row9_col0, #T_c20af_row9_col1, #T_c20af_row9_col2, #T_c20af_row9_col3, #T_c20af_row9_col5, #T_c20af_row9_col6, #T_c20af_row9_col7, #T_c20af_row10_col0, #T_c20af_row10_col1, #T_c20af_row10_col2, #T_c20af_row10_col3, #T_c20af_row10_col5, #T_c20af_row10_col6, #T_c20af_row10_col7, #T_c20af_row11_col0, #T_c20af_row11_col1, #T_c20af_row11_col2, #T_c20af_row11_col3, #T_c20af_row11_col4, #T_c20af_row11_col5, #T_c20af_row11_col6, #T_c20af_row11_col7, #T_c20af_row12_col0, #T_c20af_row12_col1, #T_c20af_row12_col2, #T_c20af_row12_col3, #T_c20af_row12_col4, #T_c20af_row12_col5, #T_c20af_row12_col6, #T_c20af_row12_col7, #T_c20af_row13_col0, #T_c20af_row13_col1, #T_c20af_row13_col2, #T_c20af_row13_col3, #T_c20af_row13_col4, #T_c20af_row13_col5, #T_c20af_row13_col6, #T_c20af_row13_col7 {
#   text-align: left;
# }
# #T_c20af_row0_col1, #T_c20af_row0_col3, #T_c20af_row0_col5, #T_c20af_row0_col6, #T_c20af_row0_col7, #T_c20af_row1_col4, #T_c20af_row2_col4, #T_c20af_row3_col2, #T_c20af_row3_col4, #T_c20af_row4_col4, #T_c20af_row5_col4, #T_c20af_row6_col4, #T_c20af_row7_col4, #T_c20af_row8_col4, #T_c20af_row9_col4, #T_c20af_row10_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c20af_row0_col8, #T_c20af_row1_col8, #T_c20af_row2_col8, #T_c20af_row4_col8, #T_c20af_row5_col8, #T_c20af_row6_col8, #T_c20af_row7_col8, #T_c20af_row8_col8, #T_c20af_row9_col8, #T_c20af_row10_col8, #T_c20af_row11_col8, #T_c20af_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c20af_row3_col8, #T_c20af_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c20af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c20af_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c20af_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c20af_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c20af_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c20af_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c20af_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c20af_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c20af_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c20af_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c20af_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_c20af_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_c20af_row0_col1" class="data row0 col1" >0.9887</td>
#       <td id="T_c20af_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_c20af_row0_col3" class="data row0 col3" >0.5621</td>
#       <td id="T_c20af_row0_col4" class="data row0 col4" >0.7041</td>
#       <td id="T_c20af_row0_col5" class="data row0 col5" >0.6173</td>
#       <td id="T_c20af_row0_col6" class="data row0 col6" >0.6117</td>
#       <td id="T_c20af_row0_col7" class="data row0 col7" >0.6196</td>
#       <td id="T_c20af_row0_col8" class="data row0 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_c20af_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_c20af_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_c20af_row1_col1" class="data row1 col1" >0.9877</td>
#       <td id="T_c20af_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_c20af_row1_col3" class="data row1 col3" >0.2414</td>
#       <td id="T_c20af_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_c20af_row1_col5" class="data row1 col5" >0.3847</td>
#       <td id="T_c20af_row1_col6" class="data row1 col6" >0.3809</td>
#       <td id="T_c20af_row1_col7" class="data row1 col7" >0.4839</td>
#       <td id="T_c20af_row1_col8" class="data row1 col8" >0.0910</td>
#     </tr>
#     <tr>
#       <th id="T_c20af_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_c20af_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_c20af_row2_col1" class="data row2 col1" >0.9875</td>
#       <td id="T_c20af_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_c20af_row2_col3" class="data row2 col3" >0.2310</td>
#       <td id="T_c20af_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_c20af_row2_col5" class="data row2 col5" >0.3703</td>
#       <td id="T_c20af_row2_col6" class="data row2 col6" >0.3666</td>
#       <td id="T_c20af_row2_col7" class="data row2 col7" >0.4722</td>
#       <td id="T_c20af_row2_col8" class="data row2 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_c20af_level0_row3" class="row_heading level0 row3" >svm</th>
#       <td id="T_c20af_row3_col0" class="data row3 col0" >SVM - Linear Kernel</td>
#       <td id="T_c20af_row3_col1" class="data row3 col1" >0.9875</td>
#       <td id="T_c20af_row3_col2" class="data row3 col2" >0.9107</td>
#       <td id="T_c20af_row3_col3" class="data row3 col3" >0.2310</td>
#       <td id="T_c20af_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_c20af_row3_col5" class="data row3 col5" >0.3703</td>
#       <td id="T_c20af_row3_col6" class="data row3 col6" >0.3666</td>
#       <td id="T_c20af_row3_col7" class="data row3 col7" >0.4722</td>
#       <td id="T_c20af_row3_col8" class="data row3 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_c20af_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_c20af_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_c20af_row4_col1" class="data row4 col1" >0.9875</td>
#       <td id="T_c20af_row4_col2" class="data row4 col2" >0.9104</td>
#       <td id="T_c20af_row4_col3" class="data row4 col3" >0.2310</td>
#       <td id="T_c20af_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_c20af_row4_col5" class="data row4 col5" >0.3703</td>
#       <td id="T_c20af_row4_col6" class="data row4 col6" >0.3666</td>
#       <td id="T_c20af_row4_col7" class="data row4 col7" >0.4722</td>
#       <td id="T_c20af_row4_col8" class="data row4 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_c20af_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_c20af_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_c20af_row5_col1" class="data row5 col1" >0.9875</td>
#       <td id="T_c20af_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_c20af_row5_col3" class="data row5 col3" >0.2310</td>
#       <td id="T_c20af_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_c20af_row5_col5" class="data row5 col5" >0.3703</td>
#       <td id="T_c20af_row5_col6" class="data row5 col6" >0.3666</td>
#       <td id="T_c20af_row5_col7" class="data row5 col7" >0.4722</td>
#       <td id="T_c20af_row5_col8" clas
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# <style type="text/css">
# #T_1e1a7_row10_col0, #T_1e1a7_row10_col1, #T_1e1a7_row10_col2, #T_1e1a7_row10_col3, #T_1e1a7_row10_col4, #T_1e1a7_row10_col5, #T_1e1a7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1e1a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e1a7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1e1a7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1e1a7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1e1a7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1e1a7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1e1a7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1e1a7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e1a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e1a7_row0_col0" class="data row0 col0" >0.9899</td>
#       <td id="T_1e1a7_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_1e1a7_row0_col2" class="data row0 col2" >0.5517</td>
#       <td id="T_1e1a7_row0_col3" class="data row0 col3" >0.7619</td>
#       <td id="T_1e1a7_row0_col4" class="data row0 col4" >0.6400</td>
#       <td id="T_1e1a7_row0_col5" class="data row0 col5" >0.6350</td>
#       <td id="T_1e1a7_row0_col6" class="data row0 col6" >0.6436</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e1a7_row1_col0" class="data row1 col0" >0.9866</td>
#       <td id="T_1e1a7_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_1e1a7_row1_col2" class="data row1 col2" >0.4828</td>
#       <td id="T_1e1a7_row1_col3" class="data row1 col3" >0.6087</td>
#       <td id="T_1e1a7_row1_col4" class="data row1 col4" >0.5385</td>
#       <td id="T_1e1a7_row1_col5" class="data row1 col5" >0.5318</td>
#       <td id="T_1e1a7_row1_col6" class="data row1 col6" >0.5354</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e1a7_row2_col0" class="data row2 col0" >0.9888</td>
#       <td id="T_1e1a7_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_1e1a7_row2_col2" class="data row2 col2" >0.6552</td>
#       <td id="T_1e1a7_row2_col3" class="data row2 col3" >0.6552</td>
#       <td id="T_1e1a7_row2_col4" class="data row2 col4" >0.6552</td>
#       <td id="T_1e1a7_row2_col5" class="data row2 col5" >0.6495</td>
#       <td id="T_1e1a7_row2_col6" class="data row2 col6" >0.6495</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e1a7_row3_col0" class="data row3 col0" >0.9860</td>
#       <td id="T_1e1a7_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_1e1a7_row3_col2" class="data row3 col2" >0.5172</td>
#       <td id="T_1e1a7_row3_col3" class="data row3 col3" >0.5769</td>
#       <td id="T_1e1a7_row3_col4" class="data row3 col4" >0.5455</td>
#       <td id="T_1e1a7_row3_col5" class="data row3 col5" >0.5384</td>
#       <td id="T_1e1a7_row3_col6" class="data row3 col6" >0.5392</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e1a7_row4_col0" class="data row4 col0" >0.9905</td>
#       <td id="T_1e1a7_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_1e1a7_row4_col2" class="data row4 col2" >0.6897</td>
#       <td id="T_1e1a7_row4_col3" class="data row4 col3" >0.7143</td>
#       <td id="T_1e1a7_row4_col4" class="data row4 col4" >0.7018</td>
#       <td id="T_1e1a7_row4_col5" class="data row4 col5" >0.6969</td>
#       <td id="T_1e1a7_row4_col6" class="data row4 col6" >0.6970</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e1a7_row5_col0" class="data row5 col0" >0.9883</td>
#       <td id="T_1e1a7_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_1e1a7_row5_col2" class="data row5 col2" >0.5862</td>
#       <td id="T_1e1a7_row5_col3" class="data row5 col3" >0.6538</td>
#       <td id="T_1e1a7_row5_col4" class="data row5 col4" >0.6182</td>
#       <td id="T_1e1a7_row5_col5" class="data row5 col5" >0.6122</td>
#       <td id="T_1e1a7_row5_col6" class="data row5 col6" >0.6132</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e1a7_row6_col0" class="data row6 col0" >0.9883</td>
#       <td id="T_1e1a7_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_1e1a7_row6_col2" class="data row6 col2" >0.5172</td>
#       <td id="T_1e1a7_row6_col3" class="data row6 col3" >0.6818</td>
#       <td id="T_1e1a7_row6_col4" class="data row6 col4" >0.5882</td>
#       <td id="T_1e1a7_row6_col5" class="data row6 col5" >0.5824</td>
#       <td id="T_1e1a7_row6_col6" class="data row6 col6" >0.5881</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1e1a7_row7_col0" class="data row7 col0" >0.9905</td>
#       <td id="T_1e1a7_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_1e1a7_row7_col2" class="data row7 col2" >0.4483</td>
#       <td id="T_1e1a7_row7_col3" class="data row7 col3" >0.9286</td>
#       <td id="T_1e1a7_row7_col4" class="data row7 col4" >0.6047</td>
#       <td id="T_1e1a7_row7_col5" class="data row7 col5" >0.6004</td>
#       <td id="T_1e1a7_row7_col6" class="data row7 col6" >0.6416</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1e1a7_row8_col0" class="data row8 col0" >0.9922</td>
#       <td id="T_1e1a7_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_1e1a7_row8_col2" class="data row8 col2" >0.5862</td>
#       <td id="T_1e1a7_row8_col3" class="data row8 col3" >0.8947</td>
#       <td id="T_1e1a7_row8_col4" class="data row8 col4" >0.7083</td>
#       <td id="T_1e1a7_row8_col5" class="data row8 col5" >0.7045</td>
#       <td id="T_1e1a7_row8_col6" class="data row8 col6" >0.7208</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1e1a7_row9_col0" class="data row9 col0" >0.9888</td>
#       <td id="T_1e1a7_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_1e1a7_row9_col2" class="data row9 col2" >0.5517</td>
#       <td id="T_1e1a7_row9_col3" class="data row9 col3" >0.6957</td>
#       <td id="T_1e1a7_row9_col4" class="data row9 col4" >0.6154</td>
#       <td id="T_1e1a7_row9_col5" class="data row9 col5" >0.6098</td>
#       <td id="T_1e1a7_row9_col6" class="data row9 col6" >0.6140</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1e1a7_row10_col0" class="data row10 col0" >0.9890</td>
#       <td id="T_1e1a7_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_1e1a7_row10_col2" class="data row10 col2" >0.5586</td>
#       <td id="T_1e1a7_row10_col3" class="data row10 col3" >0.7172</td>
#       <td id="T_1e1a7_row10_col4" class="data row10 col4" >0.6216</td>
#       <td id="T_1e1a7_row10_col5" class="data row10 col5" >0.6161</td>
#       <td id="T_1e1a7_row10_col6" class="data row10 col6" >0.6242</td>
#     </tr>
#     <tr>
#       <th id="T_1e1a7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1e1a7_row11_col0" class="data row11 col0" >0.0018</td>
#       <td id="T_1e1a7_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_1e1a7_row11_col2" class="data row11 col2" >0.0703</td>
#       <td id="T_1e1a7_row11_col3" class="data row11 col3" >0.1092</td>
#       <td id="T_1e1a7_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 28 candidates, totalling 280 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Final tuned model performance for Linux:
# <style type="text/css">
# </style>
# <table id="T_1c63e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c63e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1c63e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1c63e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1c63e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1c63e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1c63e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1c63e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1c63e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c63e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c63e_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_1c63e_row0_col1" class="data row0 col1" >0.9867</td>
#       <td id="T_1c63e_row0_col2" class="data row0 col2" >0.8660</td>
#       <td id="T_1c63e_row0_col3" class="data row0 col3" >0.5200</td>
#       <td id="T_1c63e_row0_col4" class="data row0 col4" >0.6075</td>
#       <td id="T_1c63e_row0_col5" class="data row0 col5" >0.5603</td>
#       <td id="T_1c63e_row0_col6" class="data row0 col6" >0.5536</td>
#       <td id="T_1c63e_row0_col7" class="data row0 col7" >0.5554</td>
#     </tr>
#   </tbody>
# </table>
#              timestamp                                             tokens  \
# 17753  Dec  3 09:46:33  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# 17482  Dec  2 23:35:43  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# 9773   Nov 20 05:40:50  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# 705    Jun 11 04:09:53  ['combo', 'su(pam_unix)[5961]:', 'session', 'c...
# 12292  Nov 22 01:25:26  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# ...                ...                                                ...
# 13327  Nov 22 22:20:23  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# 12133  Nov 21 18:00:20  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# 1311   Jun 24 18:55:18  ['combo', 'ftpd[28574]:', 'connection', 'from'...
# 17224  Dec  1 20:40:48  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
# 12071  Nov 21 15:40:53  ['combo', 'kernel:', 'Out', 'of', 'Memory:', '...
#
#        warning  Label  error  prediction_label  prediction_score
# 17753        0  Linux      0                 0               1.0
# 17482        0  Linux      0                 0               1.0
# 9773         0  Linux      0                 0               1.0
# 705          0  Linux      0                 0               1.0
# 12292        0  Linux      0                 0               1.0
# ...        ...    ...    ...               ...               ...
# 13327        0  Linux      0                 0               1.0
# 12133        0  Linux      0                 0               1.0
# 1311         0  Linux      0                 0               1.0
# 17224        0  Linux      0                 0               1.0
# 12071        0  Linux      0                 0               1.0
#
# [7671 rows x 7 columns]
